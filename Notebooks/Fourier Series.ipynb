# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
plt.style.use('seaborn')
#fig = figure(1)
t= np.arange(0,2*np.pi,.1)
#ax = fig.add_subplot(111)
color=['blue','orange','green', 'violet']
n_plots=4
for i in range(1,n_plots):
    fig = figure()
    ax = fig.add_subplot(111)
    ax.annotate('$sin({}x)$'.format(i), xy=(np.pi, 0), xytext=(5.2, 0.8),fontsize=15,)
    plt.plot(t, np.sin(i*t),'orange')
    #plt.savefig('fourier_data/sin'+str(i)+'.png')
    #plt.clf()

plt.show()

#ax.annotate('$Sin({}x)$'.format(i), xy=(np.pi, 0), xytext=(5.2, 0.8),fontsize=15,arrowprops=dict(arrowstyle="->",connectionstyle="arc3"))

# %%
from scipy import signal
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

def plot_square_wave():
    t= np.arange(0,100,1)
    plt.plot(t, 1*signal.square(.02 * np.pi  * t))

def fourier_series(func,N):
    x= np.arange(0,10,.1)
    series=0
    resolution=0.2
    if func=='square': # (4/pi)* sumof(1/n*sin(n*pi*t))
        plot_square_wave()
        for n in range(1,N):
            harmonic=((4/(2*n-1)*np.pi)*np.sin(resolution*(2*n-1)*np.pi*x)/N)
            series+=harmonic
            #plot_square_wave()
            plt.plot(series)
            #plt.plot(harmonic)
          
            plt.savefig('fourier_data/figSS'+str(n)+'.png')
            #plt.clf()
                
    return series
        
    
array=fourier_series('square', 10)
plt.plot(array)

# %%
from scipy import signal
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

class Fourier:
    def __init__(self):
        self.resolution=0.4
        self.series=0
        
    def plot_square_wave(self):
        self.period=50
        self.t= np.arange(0,100,1)
        self.res=len(self.t)/self.period
        plt.plot(self.t, 1*signal.square(.02*self.res * np.pi  *self.t))
    
    def square(self, N=10, save=False):
        self.x = np.arange(0,10,.1)
        self.N = N
        for n in range(1,self.N):
            self.series+=((4/(2*n-1)*np.pi)*np.sin(self.resolution*(2*n-1)*np.pi*self.x)/self.N)
            plt.plot(self.series)
            self.plot_square_wave()
            if save==True:
                plt.savefig('fourier_data/fig'+str(n)+'.png')
                plt.clf()
        
        return self.series
    
    def triangular(self, N=10, save=False):
        self.x = np.arange(0,10,.1)
        self.N = N
        for n in range(1,self.N):
            self.series+=((8/n**2*np.pi**2)*np.sin(self.resolution*(2*n-1)*np.pi*self.x)/self.N)
            plt.plot(self.series)
            self.plot_square_wave()
            if save==True:
                plt.savefig('fourier_data/fig'+str(n)+'.png')
                plt.clf()
        
        return self.series

# %%
x=Fourier()
a=x.square(save=True)
plt.plot(a)

# %%
from scipy import signal
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

def plot_square_wave(): #plot a square wave
    t= np.arange(0,100,1) #x-axis range
    plt.plot(t, 1*signal.square(.02 * np.pi  * t))

#sythesis a square wave using fourier series
def fourier_series(N): 
    x= np.arange(0,10,.1)
    series=0 
    resolution=0.2
    plot_square_wave()
    for n in range(1,N):
        harmonic=((4/(2*n-1)*np.pi)*np.sin(resolution*(2*n-1)*np.pi*x)/N) 
        series+=harmonic #synthesis equation
    return series 

array=fourier_series(10) #plotting the function
plt.plot(array)
plt.savefig('fourier_data/approximation.png')
